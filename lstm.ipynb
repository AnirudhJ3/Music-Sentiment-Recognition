# %%
# !pip install opendatasets
# !pip install pandas
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.4)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.6.12)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import opendatasets as od
import pandas

od.download("https://www.kaggle.com/datasets/imsparsh/deam-mediaeval-dataset-emotional-analysis-in-music?select=features")
# Out:
# Skipping, found downloaded files in "./deam-mediaeval-dataset-emotional-analysis-in-music" (use force=True to force download)

# %%
arousal_label_file = ('./deam-mediaeval-dataset-emotional-analysis-in-music/DEAM_Annotations/annotations/annotations averaged per song/dynamic (per second annotations)/arousal.csv')
valence_label_file = ('./deam-mediaeval-dataset-emotional-analysis-in-music/DEAM_Annotations/annotations/annotations averaged per song/dynamic (per second annotations)/valence.csv')

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
# !pip install numpy pandas matplotlib tensorflow
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.2.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Load label data
annotations_arousal = pd.read_csv(arousal_label_file)
annotations_valence = pd.read_csv(valence_label_file)

# %%
annotations_arousal.head()
# Out:
#    song_id  sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# 0        2       -0.109386       -0.114942       -0.116413       -0.118613
# 1        3       -0.110846       -0.123973       -0.131103       -0.135956
# 2        4        0.222327        0.179446        0.178388        0.184056
# 3        5       -0.255613       -0.251579       -0.251958       -0.251124
# 4        7        0.464234        0.460789        0.460991        0.461046
#
#    sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# 0       -0.126457       -0.133199       -0.136855       -0.144713
# 1       -0.140775       -0.144664       -0.163118       -0.165218
# 2        0.176042        0.178720        0.176345        0.175793
# 3       -0.250763       -0.251957       -0.251957       -0.251957
# 4        0.457240        0.465702        0.471809        0.469918
#
#    sample_19000ms  ...  sample_622000ms  sample_622500ms  sample_623000ms  \
# 0       -0.138985  ...              NaN              NaN              NaN
# 1       -0.158858  ...              NaN              NaN              NaN
# 2        0.176154  ...              NaN              NaN              NaN
# 3       -0.251957  ...              NaN              NaN              NaN
# 4        0.473377  ...              NaN              NaN              NaN
#
#    sample_623500ms  sample_624000ms  sample_624500ms  sample_625000ms  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    sample_625500ms  sample_626000ms  sample_626500ms
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
#
# [5 rows x 1225 columns]

# %%
annotations_valence.head()
# Out:
#    song_id  sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# 0        2       -0.073341       -0.074661       -0.074077       -0.078154
# 1        3       -0.189702       -0.187765       -0.183740       -0.188761
# 2        4        0.154286        0.148063        0.146956        0.151180
# 3        5        0.149053        0.148260        0.147369        0.146956
# 4        7        0.342816        0.345193        0.332023        0.328887
#
#    sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# 0       -0.081588       -0.080873       -0.083611       -0.082145
# 1       -0.193704       -0.190834       -0.189041       -0.197554
# 2        0.135942        0.076832        0.084487        0.088513
# 3        0.147857        0.146927        0.145651        0.145795
# 4        0.327603        0.329011        0.327883        0.334822
#
#    sample_19000ms  ...  sample_621500ms  sample_622000ms  sample_622500ms  \
# 0       -0.081632  ...              NaN              NaN              NaN
# 1       -0.202871  ...              NaN              NaN              NaN
# 2        0.090944  ...              NaN              NaN              NaN
# 3        0.146420  ...              NaN              NaN              NaN
# 4        0.328447  ...              NaN              NaN              NaN
#
#    sample_623000ms  sample_623500ms  sample_624000ms  sample_624500ms  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    sample_625000ms  sample_625500ms  sample_626000ms
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
#
# [5 rows x 1224 columns]

# %%
import os

dir_path = r"./deam-mediaeval-dataset-emotional-analysis-in-music/DEAM_audio/MEMD_audio/"
audio_files = []

for filename in os.listdir(dir_path):
    if filename.endswith('.mp3'):
        audio_files.append(os.path.join(dir_path, filename))

# %%
from pydub import AudioSegment
import numpy as np

def load_audio_files(file_paths):
    audio_data = []
    for file in file_paths:
        audio = AudioSegment.from_mp3(file)
        samples = np.array(audio.get_array_of_samples())
        audio_data.append(samples.astype(np.float32) / 2**15)  # Normalize the samples
    return audio_data

audio_data = load_audio_files(audio_files)

# %%
def generate_spectrograms(audio_data, sr=22050, n_fft=2048, hop_length=512):
    spectrograms = []
    for y in audio_data:
        S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
        S_DB = librosa.power_to_db(S, ref=np.max)
        spectrograms.append(S_DB)
    return spectrograms

spectrograms = generate_spectrograms(audio_data)
# Out:
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.14602661 0.11126709 0.11126709] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00424194 -0.00616455 -0.00671387 ... -0.09136963 -0.11791992
#  -0.09588623] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.09890747 -0.08511353 -0.14764404 ... -0.01116943 -0.00897217
#  -0.00897217] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.0333252  -0.04226685 -0.04940796 ...  0.09371948  0.08560181
#   0.08496094] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.03393555  0.0272522   0.03973389 ... -0.00836182 -0.10009766
#  -0.00793457] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00256348 -0.00219727
#  -0.00219727] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.18304443 -0.17852783
#  -0.17852783] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.02789307 -0.01904297
#  -0.01904297] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.01235962 0.00167847 0.00167847] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.06057739 -0.05337524
#  -0.05337524] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.01034546 0.00543213 0.00543213] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.05709839 0.02926636 0.02926636] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01187134 -0.04281616 -0.01745605 ... -0.02578735 -0.07870483
#  -0.0305481 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.03060913 -0.02331543 -0.0151062  ... -0.01028442 -0.00076294
#  -0.00805664] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00372314  0.0015564  -0.0067749  ... -0.06958008 -0.0562439
#  -0.05661011] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.2111206  -0.17373657
#  -0.17373657] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   1.5258789e-04 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.1635437  -0.14569092 -0.22332764 ... -0.23703003 -0.18811035
#  -0.18756104] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0128479  -0.01239014
#  -0.01239014] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00970459 -0.02731323
#  -0.02731323] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01760864  0.0246582   0.02557373 ...  0.08752441 -0.01733398
#   0.07714844] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01165771 -0.02859497 -0.01419067 ...  0.06039429  0.04882812
#   0.04824829] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.00308228 -0.00549316  0.00680542 ...  0.07946777  0.05090332
#   0.05969238] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.03689575  0.090271    0.04751587 ... -0.01101685 -0.00683594
#  -0.00866699] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01217651  0.0196228   0.01974487 ...  0.08804321 -0.02218628
#   0.06427002] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.00363159 -0.00497437  0.02749634 ...  0.12872314  0.10018921
#   0.10757446] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0055542  -0.00759888  0.0017395  ...  0.07391357  0.0765686
#   0.07470703] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0145874  -0.01260376
#  -0.01260376] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.02328491 -0.03509521 -0.03683472 ...  0.0168457   0.00030518
#   0.00799561] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01986694 -0.00875854 -0.02056885 ... -0.09805298 -0.074646
#  -0.07833862] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.08200073  0.08200073  0.1043396  ... -0.21408081 -0.1687622
#  -0.16882324] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.18896484  0.18139648  0.26882935 ... -0.00363159  0.0017395
#   0.00497437] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.05148315 -0.09613037 -0.0614624  ...  0.13815308  0.07772827
#   0.11425781] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.18344116 0.13693237 0.13693237] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.1277771   0.13272095  0.16152954 ...  0.03451538 -0.02719116
#   0.02252197] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#   9.1552734e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.05545044 0.04309082 0.08102417 ... 0.04953003 0.0680542  0.03973389] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.07873535 -0.11672974 -0.02392578 ...  0.01809692 -0.03500366
#   0.00341797] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.19900513 -0.16973877
#  -0.16973877] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.12628174 -0.1293335  -0.1807251  ... -0.0461731  -0.02633667
#  -0.03369141] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.11108398 0.14517212 0.14517212] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.15011597 -0.11550903
#  -0.11550903] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.07519531 -0.06735229
#  -0.06735229] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01745605 -0.01727295 -0.02029419 ...  0.23434448  0.20114136
#   0.1913147 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.17279053 -0.14089966
#  -0.14089966] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01437378  0.00228882  0.02047729 ...  0.00717163 -0.08578491
#   0.00442505] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.36758423 -0.3003235
#  -0.3003235 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.09359741 0.07546997 0.07546997] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.09292603 -0.04122925
#  -0.04122925] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00241089  0.00088501 -0.0032959  ...  0.12902832 -0.03335571
#   0.10494995] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.0614624  -0.04525757 -0.07302856 ...  0.05096436  0.00390625
#   0.04626465] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.03430176 -0.01733398
#  -0.01733398] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00042725 -0.0005188   0.00152588 ...  0.06860352 -0.00494385
#   0.06494141] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.08874512 -0.10800171
#  -0.10800171] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00796509 -0.01062012
#  -0.01062012] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00064087 -0.00012207
#  -0.00091553] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.6473999  -0.58969116
#  -0.58969116] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.05352783 0.04400635 0.04400635] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.03439331 -0.05038452 -0.04742432 ...  0.0090332  -0.11315918
#   0.01477051] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.06854248 -0.0680542  -0.09515381 ...  0.03057861  0.01495361
#   0.02090454] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.11193848 -0.0112915  -0.15505981 ...  0.10333252  0.12939453
#   0.07000732] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.14553833 0.10717773 0.10717773] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.0189209   0.02432251 -0.02963257 ... -0.04385376 -0.05932617
#  -0.04165649] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00061035 -0.0007019   0.01171875 ... -0.25164795 -0.2241211
#  -0.20007324] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.02053833 -0.01504517 -0.02978516 ...  0.24139404  0.18844604
#   0.19476318] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.13311768 0.11331177 0.11331177] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.10577393 -0.0921936
#  -0.0921936 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.01470947 0.00787354 0.00787354] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.01333618 0.01019287 0.01638794 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.02935791 -0.01010132
#  -0.01010132] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.06765747 0.12576294 0.0927124  ... 0.14892578 0.0953064  0.12188721] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.3283081  -0.27023315
#  -0.27023315] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.02038574 -0.01776123  0.0213623  ... -0.00231934  0.00021362
#  -0.01242065] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.0697937  -0.04251099 -0.0881958  ...  0.1161499  -0.01223755
#   0.11642456] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.        0.        0.        ... 0.2602539 0.2315979 0.2315979] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01535034  0.02053833  0.01919556 ... -0.02526855  0.00265503
#  -0.0171814 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.0737915  0.07626343 0.07525635 ... 0.10302734 0.07012939 0.08831787] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.10818481  0.05639648 -0.1539917  ...  0.00296021  0.0463562
#   0.00170898] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.05532837 -0.04946899
#  -0.04946899] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.02050781 0.01846313 0.01846313] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.08685303 0.04907227 0.12417603 ... 0.04360962 0.01583862 0.03100586] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.06936646 -0.08691406 -0.07736206 ...  0.04556274  0.05447388
#   0.04187012] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.07739258  0.10366821  0.11013794 ... -0.00268555 -0.07110596
#  -0.00494385] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.21591187 -0.21591187 -0.28860474 ...  0.00753784  0.00787354
#   0.00787354] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.019104   0.02685547 0.0289917  ... 0.19259644 0.2038269  0.14672852] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.00775146  0.00442505 -0.00744629 ...  0.04217529 -0.04138184
#  -0.02767944] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.13070679 0.10171509 0.10171509] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.09561157 0.10635376 0.15637207 ... 0.21774292 0.16555786 0.17553711] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.16348267 0.13549805 0.13549805] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.13339233 -0.12091064 -0.16104126 ... -0.0350647  -0.02182007
#  -0.02325439] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.05599976 -0.04519653
#  -0.04519653] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01712036  0.03186035 -0.03152466 ...  0.09594727 -0.05453491
#   0.07382202] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00354004  0.03106689  0.00061035 ... -0.08493042 -0.04351807
#  -0.0668335 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.11529541 -0.11550903 -0.17324829 ...  0.05169678  0.03109741
#   0.04049683] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01333618 -0.02059937  0.00820923 ... -0.00640869 -0.01547241
#  -0.00653076] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01620483 -0.01751709  0.00982666 ... -0.0083313   0.11199951
#  -0.00662231] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.12359619 0.10345459 0.10345459] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.0178833   0.00402832 -0.03005981 ... -0.18118286  0.05477905
#  -0.11367798] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.03143311 0.02770996 0.02770996] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.00088501  0.00491333 -0.00054932 ... -0.03894043 -0.03646851
#  -0.02905273] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01565552  0.0151062   0.01373291 ... -0.10592651 -0.20962524
#  -0.08453369] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0869751   0.13635254  0.08822632 ...  0.1991272  -0.1137085
#   0.13781738] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00778198 -0.02871704 -0.00567627 ... -0.14334106 -0.17181396
#  -0.10617065] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0072937   0.00479126  0.01483154 ... -0.13656616 -0.1164856
#  -0.11260986] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01495361 -0.01992798 -0.02182007 ...  0.27548218  0.20773315
#   0.21029663] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.19308472 0.03741455 0.03741455] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.03219604  0.02859497  0.03829956 ... -0.00790405 -0.12069702
#   0.00030518] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.02639771 -0.03726196
#  -0.03726196] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.02359009 0.01821899 0.01821899] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.00048828  0.00732422 -0.00259399 ... -0.105896    0.06192017
#  -0.06570435] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.13497925 -0.13565063 -0.19616699 ...  0.14071655  0.09020996
#   0.11657715] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.11251831 -0.1572876
#  -0.1572876 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.6519165  0.56051636 0.56051636] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.07452393 -0.050354   -0.12078857 ...  0.10009766  0.05984497
#   0.07717896] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.90478516 0.7331238  0.7331238 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.1244812  0.25094604 0.17660522 ... 0.01586914 0.08187866 0.01235962] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.02597046 -0.04669189
#  -0.04669189] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0458374  -0.02215576  0.06253052 ...  0.21173096  0.10409546
#   0.16329956] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.05484009 -0.08151245 -0.08322144 ...  0.068573    0.03878784
#   0.04870605] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00927734 -0.00674438 -0.01071167 ... -0.00750732 -0.00860596
#  -0.01327515] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.0710144  0.07653809 0.07653809] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.0975647  0.08166504 0.08166504] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.03060913 0.03109741 0.0229187  ... 0.01382446 0.02087402 0.01690674] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.09762573  0.11569214  0.12963867 ... -0.06878662 -0.09805298
#  -0.08624268] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.00259399 0.00640869 0.00640869] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00558472 -0.00143433 -0.00769043 ...  0.21105957  0.19766235
#   0.16680908] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 4.5776367e-04  1.3427734e-03 -9.1552734e-05 ...  1.1584473e-01
#   7.4829102e-02  8.6608887e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.02325439  0.04367065 -0.03518677 ... -0.03289795 -0.01867676
#  -0.02511597] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.02011108 0.0163269  0.0163269 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#   1.2207031e-04  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.08636475 -0.03912354 -0.07254028 ... -0.02426147 -0.05233765
#  -0.04208374] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.037323    0.037323    0.04782104 ... -0.07601929 -0.05801392
#  -0.05801392] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.02218628  0.0305481   0.03131104 ... -0.32781982 -0.24911499
#  -0.24191284] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01193237  0.05618286 -0.02236938 ...  0.23660278  0.21600342
#   0.1843872 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00259399 -0.00845337 -0.0015564  ... -0.05685425 -0.04650879
#  -0.04675293] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00860596 -0.00680542 -0.01339722 ... -0.06335449 -0.03121948
#  -0.03219604] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0944519  -0.07894897
#  -0.07894897] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.23568726 -0.18890381
#  -0.18890381] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.02532959  0.0222168   0.0380249  ... -0.06234741 -0.03433228
#  -0.0480957 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.292511   0.26065063 0.26065063] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.03030396  0.02764893  0.03982544 ... -0.0007019   0.02850342
#   0.00646973] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.03967285 -0.02597046
#  -0.02597046] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.08267212  0.0340271  -0.09313965 ... -0.1031189  -0.04019165
#  -0.08007812] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.02496338 -0.02420044
#  -0.02420044] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.01425171 0.04174805 0.0168457  ... 0.06185913 0.06811523 0.04998779] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.02645874  0.05282593 -0.04299927 ... -0.1541748  -0.30770874
#  -0.1010437 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.18093872 -0.15264893
#  -0.15264893] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.16070557 -0.14398193
#  -0.14398193] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.07937622  0.08059692  0.04315186 ...  0.00140381 -0.01254272
#  -0.01577759] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00976562 -0.00762939 -0.01205444 ...  0.05786133  0.03903198
#   0.04934692] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.08319092 0.0774231  0.11477661 ... 0.05621338 0.0446167  0.04458618] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.02111816 -0.07574463  0.02505493 ... -0.07995605 -0.07794189
# ...
#  -0.14675903] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.08105469 -0.07058716 -0.1184082  ... -0.01339722 -0.01138306
#  -0.00997925] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.0163269   0.01705933  0.02160645 ... -0.09078979 -0.07843018
#  -0.0708313 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.03979492 -0.04473877 -0.05352783 ... -0.07611084 -0.05838013
#  -0.05587769] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.07208252 0.06655884 0.06655884] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00830078 -0.01754761 -0.02633667 ...  0.1237793   0.10540771
#   0.09213257] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.2833557  -0.22290039
#  -0.22290039] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.03570557 -0.08712769 -0.04595947 ...  0.32644653  0.07098389
#   0.26400757] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.00045776 0.00030518 0.00030518] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.23675537 0.20385742 0.20385742] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.10723877 -0.09606934
#  -0.09606934] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.12487793  0.12487793  0.18847656 ... -0.0328064  -0.02606201
#  -0.02606201] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.05493164 -0.06741333 -0.0696106  ...  0.02423096  0.012146
#   0.01528931] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.07839966 -0.10214233 -0.10375977 ...  0.30026245  0.20535278
#   0.21350098] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0559082  -0.04101562
#  -0.04101562] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0753479  -0.09973145
#  -0.09973145] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.09405518 -0.14627075 -0.12548828 ... -0.20169067 -0.18548584
#  -0.16738892] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.04556274 -0.13342285 -0.06259155 ... -0.12710571 -0.05633545
#  -0.09677124] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.14056396  0.09292603  0.19522095 ... -0.19943237 -0.07305908
#  -0.1687622 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.5062866  -0.41714478
#  -0.41714478] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.06045532 0.05072021 0.05072021] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.08309937 -0.1109314  -0.10644531 ... -0.14691162 -0.11846924
#  -0.10586548] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01763916 -0.07955933 -0.02481079 ... -0.06695557  0.03759766
#  -0.05029297] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.09719849  0.07095337  0.11767578 ...  0.0345459  -0.1793518
#   0.01324463] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.        0.        0.        ... 0.4930725 0.4199829 0.4199829] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.04098511 -0.00305176
#  -0.00305176] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.01074219  0.065979    0.01559448 ... -0.11306763 -0.09915161
#  -0.08615112] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.11004639 -0.0791626   0.1159668  ... -0.14324951  0.0758667
#  -0.11077881] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01644897 -0.01837158 -0.02105713 ...  0.08297729  0.23226929
#   0.06298828] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.0171814  -0.01046753 -0.01425171 ...  0.00628662 -0.03753662
#  -0.01132202] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.00170898 0.00195312 0.00195312] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.0062561  -0.01504517
#  -0.01504517] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.09661865 -0.08300781
#  -0.08300781] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00082397 -0.00137329
#  -0.00137329] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.01916504 -0.00814819
#  -0.00814819] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.12677002 0.09817505 0.09817505] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.00311279  0.01022339  0.00384521 ...  0.00021362 -0.00701904
#   0.00036621] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.01721191 -0.04364014 -0.02853394 ... -0.00698853 -0.01394653
#  -0.00872803] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.13623047 -0.02288818 -0.16174316 ... -0.0418396  -0.02935791
#  -0.03570557] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.01937866 0.02151489 0.02151489] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.00073242 -0.0090332  -0.01391602 ... -0.21899414 -0.15072632
#  -0.17147827] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.0071106  0.00918579 0.00918579] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.05105591 0.0345459  0.0345459 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.05700684 -0.0319519  -0.08117676 ...  0.02664185  0.00924683
#   0.02270508] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.0057373  0.00439453 0.00570679 ... 0.15563965 0.13705444 0.11749268] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.03250122 -0.01733398 -0.06488037 ...  0.09448242  0.07406616
#   0.07992554] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.24542236 0.2050476  0.2970276  ... 0.29470825 0.28771973 0.22854614] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[-0.03201294  0.04241943 -0.04431152 ...  0.09063721 -0.09524536
#   0.07006836] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.06658936 -0.05535889
#  -0.05535889] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.10263062 0.07321167 0.07321167] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)
# <ipython-input-89-bec94ec1faae>:4: FutureWarning: Pass y=[0.         0.         0.         ... 0.20343018 0.168396   0.168396  ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_fft=n_fft, hop_length=hop_length)

# %%
def align_spectrograms_with_annotations(spectrograms, annotations, interval=500):
    aligned_data = []
    for i, S_DB in enumerate(spectrograms):
        num_frames = S_DB.shape[1]
        num_intervals = int(num_frames * interval / 1000)
        annotation = annotations.iloc[i]
        # Resample annotation to match the number of spectrogram frames
        annotation_resampled = np.interp(
            np.linspace(0, len(annotation)-1, num_intervals),
            np.arange(len(annotation)),
            annotation
        )
        aligned_data.append((S_DB.T, annotation_resampled))
    return aligned_data

aligned_data_arousal = align_spectrograms_with_annotations(spectrograms, annotations_arousal)
aligned_data_valence = align_spectrograms_with_annotations(spectrograms, annotations_valence)

# %%
def align_spectrograms_with_annotations(spectrograms, annotations, interval=500):
    aligned_data = []
    for i, S_DB in enumerate(spectrograms):
        num_frames = S_DB.shape[1]
        annotation = annotations.iloc[i]
        annotation = annotations.iloc[i].fillna(0)
        num_intervals = len(annotation)

        # Ensure that the number of intervals matches the number of frames
        if num_frames != num_intervals:
            # Resample the annotations to match the number of spectrogram frames
            annotation_resampled = np.interp(
                np.linspace(0, num_intervals - 1, num_frames),
                np.arange(num_intervals),
                annotation
            )
        else:
            annotation_resampled = annotation

        aligned_data.append((S_DB.T, annotation_resampled))
    return aligned_data

aligned_data_arousal = align_spectrograms_with_annotations(spectrograms, annotations_arousal)
aligned_data_valence = align_spectrograms_with_annotations(spectrograms, annotations_valence)

# %%
aligned_data = [(x, y1, y2) for (x, y1), (_, y2) in zip(aligned_data_arousal, aligned_data_valence)]

# Prepare X and y for model input
X = []
y_arousal = []
y_valence = []
for x, y1, y2 in aligned_data:
  X.append(x)
  y_arousal.append(y1)
  y_valence.append(y2)

# %%
X = np.array(X)
y_arousal = np.array(y_arousal)
y_valence = np.array(y_valence)

# Scale the data
scaler = MinMaxScaler()
X_scaled = np.array([scaler.fit_transform(x) for x in X])

# Split into training and testing sets
X_train, X_test, y_train_arousal, y_test_arousal, y_train_valence, y_test_valence = train_test_split(
    X_scaled, y_arousal, y_valence, test_size=0.2, random_state=42
)

# %%
# Define LSTM model
def build_lstm_model(input_shape):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        LSTM(64, return_sequences=True),
        TimeDistributed(Dense(1, activation='linear'))
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

input_shape = (X_train.shape[1], X_train.shape[2])
model_arousal = build_lstm_model(input_shape)
model_valence = build_lstm_model(input_shape)

# Train the model
history_arousal = model_arousal.fit(X_train, y_train_arousal, epochs=1000, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/1000
# 36/36 [==============================] - 10s 210ms/step - loss: 1513.6290 - mae: 1.7461 - val_loss: 1707.7422 - val_mae: 1.8255
# Epoch 2/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1498.9626 - mae: 1.7299 - val_loss: 1695.0752 - val_mae: 1.8609
# Epoch 3/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1488.8016 - mae: 1.7176 - val_loss: 1684.9429 - val_mae: 1.8727
# Epoch 4/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1479.5615 - mae: 1.7000 - val_loss: 1675.1442 - val_mae: 1.8192
# Epoch 5/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1470.8335 - mae: 1.6853 - val_loss: 1665.9991 - val_mae: 1.7986
# Epoch 6/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1462.1957 - mae: 1.6788 - val_loss: 1657.2437 - val_mae: 1.8101
# Epoch 7/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1454.3607 - mae: 1.6880 - val_loss: 1649.0242 - val_mae: 1.7844
# Epoch 8/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1446.3943 - mae: 1.6577 - val_loss: 1640.0970 - val_mae: 1.8295
# Epoch 9/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1438.6360 - mae: 1.6709 - val_loss: 1631.9056 - val_mae: 1.7733
# Epoch 10/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1431.0962 - mae: 1.6544 - val_loss: 1623.8448 - val_mae: 1.7708
# Epoch 11/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1423.7552 - mae: 1.6403 - val_loss: 1616.3804 - val_mae: 1.7950
# Epoch 12/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1416.7052 - mae: 1.6577 - val_loss: 1608.6235 - val_mae: 1.8224
# Epoch 13/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1409.7670 - mae: 1.6473 - val_loss: 1601.1392 - val_mae: 1.7973
# Epoch 14/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1402.8970 - mae: 1.6513 - val_loss: 1593.9812 - val_mae: 1.7446
# Epoch 15/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1396.0043 - mae: 1.6205 - val_loss: 1586.8834 - val_mae: 1.7415
# Epoch 16/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1389.0696 - mae: 1.6466 - val_loss: 1580.9622 - val_mae: 1.7562
# Epoch 17/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1383.5502 - mae: 1.6258 - val_loss: 1572.8407 - val_mae: 1.7253
# Epoch 18/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1376.5273 - mae: 1.6054 - val_loss: 1565.5599 - val_mae: 1.7476
# Epoch 19/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1370.2832 - mae: 1.6212 - val_loss: 1559.2267 - val_mae: 1.7196
# Epoch 20/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1364.0780 - mae: 1.5978 - val_loss: 1552.2754 - val_mae: 1.7266
# Epoch 21/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1357.4437 - mae: 1.5872 - val_loss: 1546.5013 - val_mae: 1.6855
# Epoch 22/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1352.5513 - mae: 1.5937 - val_loss: 1540.1178 - val_mae: 1.6753
# Epoch 23/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1346.1969 - mae: 1.5725 - val_loss: 1533.2394 - val_mae: 1.6738
# Epoch 24/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1340.1145 - mae: 1.5715 - val_loss: 1527.3235 - val_mae: 1.6985
# Epoch 25/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1334.7075 - mae: 1.5898 - val_loss: 1520.9252 - val_mae: 1.6743
# Epoch 26/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1328.2434 - mae: 1.5851 - val_loss: 1514.4987 - val_mae: 1.7378
# Epoch 27/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1322.8719 - mae: 1.5796 - val_loss: 1508.1256 - val_mae: 1.6924
# Epoch 28/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1317.3975 - mae: 1.5720 - val_loss: 1502.4679 - val_mae: 1.6991
# Epoch 29/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1312.2406 - mae: 1.5722 - val_loss: 1497.0482 - val_mae: 1.6650
# Epoch 30/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1306.3726 - mae: 1.5579 - val_loss: 1491.0192 - val_mae: 1.6625
# Epoch 31/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1299.8684 - mae: 1.5533 - val_loss: 1487.8214 - val_mae: 1.6342
# Epoch 32/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1296.6074 - mae: 1.5671 - val_loss: 1479.3906 - val_mae: 1.8851
# Epoch 33/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1289.9352 - mae: 1.6134 - val_loss: 1473.1198 - val_mae: 1.6569
# Epoch 34/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1284.2721 - mae: 1.5361 - val_loss: 1468.2583 - val_mae: 1.7321
# Epoch 35/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1280.8247 - mae: 1.5991 - val_loss: 1462.6104 - val_mae: 1.6986
# Epoch 36/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1274.5396 - mae: 1.6096 - val_loss: 1456.5968 - val_mae: 1.7457
# Epoch 37/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1268.6427 - mae: 1.5666 - val_loss: 1451.0981 - val_mae: 1.6419
# Epoch 38/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1262.3812 - mae: 1.5273 - val_loss: 1444.7593 - val_mae: 1.6551
# Epoch 39/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1258.2651 - mae: 1.5449 - val_loss: 1443.7567 - val_mae: 1.5983
# Epoch 40/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1255.0581 - mae: 1.5368 - val_loss: 1435.4719 - val_mae: 1.6547
# Epoch 41/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1248.5470 - mae: 1.5394 - val_loss: 1430.7168 - val_mae: 1.5923
# Epoch 42/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1242.5765 - mae: 1.5172 - val_loss: 1424.1353 - val_mae: 1.6202
# Epoch 43/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1237.2769 - mae: 1.5236 - val_loss: 1417.7150 - val_mae: 1.6706
# Epoch 44/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1231.7056 - mae: 1.5278 - val_loss: 1413.7878 - val_mae: 1.6245
# Epoch 45/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1227.2994 - mae: 1.5295 - val_loss: 1407.6390 - val_mae: 1.6078
# Epoch 46/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1223.4283 - mae: 1.5210 - val_loss: 1403.8868 - val_mae: 1.8171
# Epoch 47/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1217.3417 - mae: 1.5572 - val_loss: 1396.5819 - val_mae: 1.6293
# Epoch 48/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1212.0632 - mae: 1.5507 - val_loss: 1391.7334 - val_mae: 1.6764
# Epoch 49/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1208.1094 - mae: 1.5713 - val_loss: 1387.2557 - val_mae: 1.6076
# Epoch 50/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1202.4015 - mae: 1.5095 - val_loss: 1383.2499 - val_mae: 1.5946
# Epoch 51/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1197.3441 - mae: 1.5168 - val_loss: 1377.6476 - val_mae: 1.6653
# Epoch 52/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1192.6693 - mae: 1.4901 - val_loss: 1372.4232 - val_mae: 1.6716
# Epoch 53/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1188.9858 - mae: 1.5590 - val_loss: 1366.7732 - val_mae: 1.6033
# Epoch 54/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1182.6906 - mae: 1.4687 - val_loss: 1360.8695 - val_mae: 1.5946
# Epoch 55/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1177.9054 - mae: 1.4804 - val_loss: 1359.4572 - val_mae: 1.6387
# Epoch 56/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1178.5292 - mae: 1.5828 - val_loss: 1354.6659 - val_mae: 1.5998
# Epoch 57/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1172.7035 - mae: 1.4982 - val_loss: 1348.0841 - val_mae: 1.6181
# Epoch 58/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1166.8842 - mae: 1.4912 - val_loss: 1343.6736 - val_mae: 1.5906
# Epoch 59/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1161.5870 - mae: 1.4574 - val_loss: 1337.4453 - val_mae: 1.5405
# Epoch 60/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1156.1658 - mae: 1.4678 - val_loss: 1333.8888 - val_mae: 1.5754
# Epoch 61/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1155.2446 - mae: 1.4737 - val_loss: 1328.9253 - val_mae: 1.6433
# Epoch 62/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1149.6244 - mae: 1.5229 - val_loss: 1322.2566 - val_mae: 1.5855
# Epoch 63/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1143.7068 - mae: 1.4760 - val_loss: 1317.7933 - val_mae: 1.7086
# Epoch 64/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1139.7651 - mae: 1.4593 - val_loss: 1310.9819 - val_mae: 1.6072
# Epoch 65/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1134.6714 - mae: 1.4468 - val_loss: 1307.6454 - val_mae: 1.5521
# Epoch 66/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1129.2128 - mae: 1.4379 - val_loss: 1303.6284 - val_mae: 1.5453
# Epoch 67/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1124.2711 - mae: 1.4476 - val_loss: 1298.6582 - val_mae: 1.5235
# Epoch 68/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 1120.0635 - mae: 1.4325 - val_loss: 1296.4182 - val_mae: 1.7247
# Epoch 69/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1115.2886 - mae: 1.4345 - val_loss: 1292.3801 - val_mae: 1.4878
# Epoch 70/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1111.1255 - mae: 1.4061 - val_loss: 1286.5367 - val_mae: 1.6057
# Epoch 71/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1108.6965 - mae: 1.4194 - val_loss: 1282.8666 - val_mae: 1.4962
# Epoch 72/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1103.7969 - mae: 1.4088 - val_loss: 1277.7041 - val_mae: 1.5017
# Epoch 73/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1099.3708 - mae: 1.4216 - val_loss: 1275.1932 - val_mae: 1.4829
# Epoch 74/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1095.1505 - mae: 1.4363 - val_loss: 1267.3584 - val_mae: 1.6219
# Epoch 75/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1090.4113 - mae: 1.4233 - val_loss: 1262.7380 - val_mae: 1.5284
# Epoch 76/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1086.1613 - mae: 1.4041 - val_loss: 1259.4612 - val_mae: 1.4849
# Epoch 77/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1082.0956 - mae: 1.3899 - val_loss: 1255.1718 - val_mae: 1.4839
# Epoch 78/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1077.7443 - mae: 1.4085 - val_loss: 1248.6455 - val_mae: 1.4922
# Epoch 79/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1074.1819 - mae: 1.3733 - val_loss: 1250.3239 - val_mae: 1.4671
# Epoch 80/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1071.5006 - mae: 1.4007 - val_loss: 1244.3712 - val_mae: 1.6242
# Epoch 81/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1067.8203 - mae: 1.4297 - val_loss: 1234.9835 - val_mae: 1.5250
# Epoch 82/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1062.4919 - mae: 1.3767 - val_loss: 1233.0426 - val_mae: 1.5410
# Epoch 83/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1057.4116 - mae: 1.4125 - val_loss: 1232.7621 - val_mae: 1.4862
# Epoch 84/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1054.7000 - mae: 1.4087 - val_loss: 1223.7061 - val_mae: 1.4645
# Epoch 85/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1050.5134 - mae: 1.3708 - val_loss: 1221.7257 - val_mae: 1.5768
# Epoch 86/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1046.7726 - mae: 1.3913 - val_loss: 1214.1019 - val_mae: 1.4772
# Epoch 87/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1041.0908 - mae: 1.3600 - val_loss: 1215.0052 - val_mae: 1.5270
# Epoch 88/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1038.0219 - mae: 1.3722 - val_loss: 1206.4819 - val_mae: 1.5121
# Epoch 89/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1035.1597 - mae: 1.3871 - val_loss: 1200.5166 - val_mae: 1.4783
# Epoch 90/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1030.3269 - mae: 1.3633 - val_loss: 1194.7081 - val_mae: 1.5151
# Epoch 91/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1027.7173 - mae: 1.3735 - val_loss: 1196.6008 - val_mae: 1.4510
# Epoch 92/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 1024.2394 - mae: 1.3579 - val_loss: 1192.2910 - val_mae: 1.4603
# Epoch 93/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1019.1540 - mae: 1.3742 - val_loss: 1187.1609 - val_mae: 1.5104
# Epoch 94/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 1016.0845 - mae: 1.3737 - val_loss: 1179.0934 - val_mae: 1.4550
# Epoch 95/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1010.9583 - mae: 1.3394 - val_loss: 1176.6235 - val_mae: 1.4349
# Epoch 96/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 1007.7551 - mae: 1.3416 - val_loss: 1176.1738 - val_mae: 1.4439
# Epoch 97/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1004.3270 - mae: 1.3305 - val_loss: 1167.4937 - val_mae: 1.4948
# Epoch 98/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 1001.4017 - mae: 1.3341 - val_loss: 1167.4335 - val_mae: 1.4376
# Epoch 99/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 996.0782 - mae: 1.3402 - val_loss: 1164.0748 - val_mae: 1.4267
# Epoch 100/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 992.0511 - mae: 1.3240 - val_loss: 1161.2421 - val_mae: 1.4331
# Epoch 101/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 988.6560 - mae: 1.3266 - val_loss: 1158.6917 - val_mae: 1.4884
# Epoch 102/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 985.0529 - mae: 1.3173 - val_loss: 1153.9939 - val_mae: 1.4678
# Epoch 103/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 981.6545 - mae: 1.3224 - val_loss: 1142.2045 - val_mae: 1.4392
# Epoch 104/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 977.8290 - mae: 1.3135 - val_loss: 1151.5582 - val_mae: 1.3978
# Epoch 105/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 976.7341 - mae: 1.3571 - val_loss: 1143.9559 - val_mae: 1.4158
# Epoch 106/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 971.4865 - mae: 1.3158 - val_loss: 1131.8907 - val_mae: 1.4012
# Epoch 107/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 967.6175 - mae: 1.3042 - val_loss: 1124.1456 - val_mae: 1.4168
# Epoch 108/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 964.7469 - mae: 1.3201 - val_loss: 1135.1179 - val_mae: 1.4945
# Epoch 109/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 967.0307 - mae: 1.4129 - val_loss: 1130.6951 - val_mae: 1.5593
# Epoch 110/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 959.2473 - mae: 1.3371 - val_loss: 1122.1730 - val_mae: 1.4306
# Epoch 111/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 954.5630 - mae: 1.3005 - val_loss: 1119.1653 - val_mae: 1.4191
# Epoch 112/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 951.1328 - mae: 1.2879 - val_loss: 1108.7423 - val_mae: 1.4365
# Epoch 113/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 954.8308 - mae: 1.3868 - val_loss: 1117.1871 - val_mae: 1.6950
# Epoch 114/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 946.5790 - mae: 1.4155 - val_loss: 1109.5104 - val_mae: 1.4255
# Epoch 115/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 941.6144 - mae: 1.2932 - val_loss: 1106.3357 - val_mae: 1.3842
# Epoch 116/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 937.7875 - mae: 1.2853 - val_loss: 1102.8936 - val_mae: 1.4256
# Epoch 117/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 933.8942 - mae: 1.2841 - val_loss: 1098.2634 - val_mae: 1.3990
# Epoch 118/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 930.5660 - mae: 1.2660 - val_loss: 1098.0503 - val_mae: 1.4013
# Epoch 119/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 927.3828 - mae: 1.2621 - val_loss: 1089.9341 - val_mae: 1.3972
# Epoch 120/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 923.9828 - mae: 1.2838 - val_loss: 1089.6146 - val_mae: 1.3856
# Epoch 121/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 921.4346 - mae: 1.2737 - val_loss: 1081.6530 - val_mae: 1.4674
# Epoch 122/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 918.4858 - mae: 1.2702 - val_loss: 1079.8677 - val_mae: 1.3784
# Epoch 123/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 914.2050 - mae: 1.2585 - val_loss: 1080.3140 - val_mae: 1.3561
# Epoch 124/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 910.7922 - mae: 1.2952 - val_loss: 1080.6519 - val_mae: 1.4222
# Epoch 125/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 908.5189 - mae: 1.2662 - val_loss: 1066.5164 - val_mae: 1.3682
# Epoch 126/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 904.8273 - mae: 1.2660 - val_loss: 1071.4780 - val_mae: 1.4041
# Epoch 127/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 901.7241 - mae: 1.2623 - val_loss: 1063.4285 - val_mae: 1.4363
# Epoch 128/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 898.2527 - mae: 1.2776 - val_loss: 1058.9260 - val_mae: 1.3872
# Epoch 129/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 895.2847 - mae: 1.2900 - val_loss: 1058.0880 - val_mae: 1.3616
# Epoch 130/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 892.8346 - mae: 1.2767 - val_loss: 1053.8801 - val_mae: 1.3623
# Epoch 131/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 894.1220 - mae: 1.2687 - val_loss: 1049.9857 - val_mae: 1.4058
# Epoch 132/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 888.3738 - mae: 1.2732 - val_loss: 1049.1226 - val_mae: 1.3600
# Epoch 133/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 883.7521 - mae: 1.3007 - val_loss: 1051.0358 - val_mae: 1.3579
# Epoch 134/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 882.2487 - mae: 1.2494 - val_loss: 1044.1349 - val_mae: 1.3374
# Epoch 135/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 878.2119 - mae: 1.2715 - val_loss: 1040.2904 - val_mae: 1.3544
# Epoch 136/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 874.1533 - mae: 1.2385 - val_loss: 1036.8252 - val_mae: 1.3303
# Epoch 137/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 871.1804 - mae: 1.2473 - val_loss: 1035.1936 - val_mae: 1.3894
# Epoch 138/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 867.5063 - mae: 1.2280 - val_loss: 1027.2152 - val_mae: 1.3263
# Epoch 139/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 864.5448 - mae: 1.2248 - val_loss: 1024.9512 - val_mae: 1.3419
# Epoch 140/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 861.3461 - mae: 1.2175 - val_loss: 1025.7485 - val_mae: 1.3463
# Epoch 141/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 858.3072 - mae: 1.1962 - val_loss: 1015.2217 - val_mae: 1.3345
# Epoch 142/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 855.7812 - mae: 1.2368 - val_loss: 1017.0645 - val_mae: 1.3315
# Epoch 143/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 852.9725 - mae: 1.2156 - val_loss: 1016.5372 - val_mae: 1.3730
# Epoch 144/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 849.9138 - mae: 1.2177 - val_loss: 1007.8318 - val_mae: 1.4122
# Epoch 145/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 847.5056 - mae: 1.2446 - val_loss: 1011.8912 - val_mae: 1.3382
# Epoch 146/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 845.1689 - mae: 1.2129 - val_loss: 1004.3781 - val_mae: 1.3679
# Epoch 147/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 841.4237 - mae: 1.2239 - val_loss: 1002.6786 - val_mae: 1.3274
# Epoch 148/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 839.8738 - mae: 1.2745 - val_loss: 1000.7936 - val_mae: 1.3458
# Epoch 149/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 836.1874 - mae: 1.2417 - val_loss: 994.0739 - val_mae: 1.3115
# Epoch 150/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 833.8549 - mae: 1.2142 - val_loss: 986.1716 - val_mae: 1.3996
# Epoch 151/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 830.6667 - mae: 1.2282 - val_loss: 993.2770 - val_mae: 1.3663
# Epoch 152/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 826.9609 - mae: 1.2057 - val_loss: 989.9235 - val_mae: 1.3112
# Epoch 153/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 824.4100 - mae: 1.2222 - val_loss: 982.6279 - val_mae: 1.3095
# Epoch 154/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 821.2401 - mae: 1.2021 - val_loss: 978.2651 - val_mae: 1.3180
# Epoch 155/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 818.7863 - mae: 1.2313 - val_loss: 982.4634 - val_mae: 1.3236
# Epoch 156/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 816.3362 - mae: 1.2010 - val_loss: 967.7092 - val_mae: 1.3695
# Epoch 157/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 813.4058 - mae: 1.1969 - val_loss: 968.6884 - val_mae: 1.3221
# Epoch 158/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 810.2629 - mae: 1.1821 - val_loss: 967.6432 - val_mae: 1.4890
# Epoch 159/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 807.5292 - mae: 1.2217 - val_loss: 967.1329 - val_mae: 1.3117
# Epoch 160/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 804.9354 - mae: 1.1996 - val_loss: 960.0875 - val_mae: 1.2997
# Epoch 161/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 802.7009 - mae: 1.1987 - val_loss: 958.2386 - val_mae: 1.3913
# Epoch 162/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 800.0978 - mae: 1.2208 - val_loss: 959.4770 - val_mae: 1.3225
# Epoch 163/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 796.4768 - mae: 1.2097 - val_loss: 952.9581 - val_mae: 1.3180
# Epoch 164/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 794.1213 - mae: 1.1906 - val_loss: 955.7796 - val_mae: 1.3243
# Epoch 165/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 791.9440 - mae: 1.2716 - val_loss: 951.6802 - val_mae: 1.3434
# Epoch 166/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 790.7166 - mae: 1.1908 - val_loss: 944.1858 - val_mae: 1.2965
# Epoch 167/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 787.2644 - mae: 1.2016 - val_loss: 949.0327 - val_mae: 1.3072
# Epoch 168/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 783.9650 - mae: 1.2278 - val_loss: 947.3045 - val_mae: 1.2861
# Epoch 169/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 781.7018 - mae: 1.2240 - val_loss: 942.0876 - val_mae: 1.3401
# Epoch 170/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 779.1453 - mae: 1.2001 - val_loss: 936.4074 - val_mae: 1.3113
# Epoch 171/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 776.6012 - mae: 1.2152 - val_loss: 938.0266 - val_mae: 1.3542
# Epoch 172/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 774.2330 - mae: 1.1806 - val_loss: 935.9307 - val_mae: 1.3375
# Epoch 173/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 771.1780 - mae: 1.1673 - val_loss: 935.7961 - val_mae: 1.2807
# Epoch 174/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 768.5771 - mae: 1.2116 - val_loss: 932.4285 - val_mae: 1.3819
# Epoch 175/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 774.0185 - mae: 1.2339 - val_loss: 926.2954 - val_mae: 1.3252
# Epoch 176/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 772.2161 - mae: 1.2827 - val_loss: 918.2144 - val_mae: 1.4754
# Epoch 177/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 765.4315 - mae: 1.2600 - val_loss: 913.9359 - val_mae: 1.3312
# Epoch 178/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 760.7181 - mae: 1.2298 - val_loss: 913.4777 - val_mae: 1.4059
# Epoch 179/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 757.5911 - mae: 1.2353 - val_loss: 918.2074 - val_mae: 1.2948
# Epoch 180/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 754.4866 - mae: 1.1814 - val_loss: 909.3223 - val_mae: 1.2820
# Epoch 181/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 751.5385 - mae: 1.1588 - val_loss: 909.1675 - val_mae: 1.2719
# Epoch 182/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 749.4899 - mae: 1.1711 - val_loss: 907.8430 - val_mae: 1.2568
# Epoch 183/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 746.0465 - mae: 1.1882 - val_loss: 904.7859 - val_mae: 1.2973
# Epoch 184/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 743.7435 - mae: 1.1645 - val_loss: 907.1821 - val_mae: 1.3142
# Epoch 185/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 747.7839 - mae: 1.2278 - val_loss: 897.8253 - val_mae: 1.3662
# Epoch 186/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 739.8406 - mae: 1.1934 - val_loss: 898.8020 - val_mae: 1.3264
# Epoch 187/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 737.9767 - mae: 1.1894 - val_loss: 892.7873 - val_mae: 1.2743
# Epoch 188/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 735.1064 - mae: 1.1568 - val_loss: 894.0275 - val_mae: 1.2757
# Epoch 189/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 732.4736 - mae: 1.1304 - val_loss: 893.3080 - val_mae: 1.3696
# Epoch 190/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 730.3206 - mae: 1.1470 - val_loss: 890.2975 - val_mae: 1.2665
# Epoch 191/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 728.0576 - mae: 1.1407 - val_loss: 888.1137 - val_mae: 1.3313
# Epoch 192/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 726.7802 - mae: 1.1772 - val_loss: 881.2759 - val_mae: 1.2746
# Epoch 193/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 723.6948 - mae: 1.1717 - val_loss: 876.9590 - val_mae: 1.3089
# Epoch 194/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 721.4464 - mae: 1.1555 - val_loss: 879.1863 - val_mae: 1.2620
# Epoch 195/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 722.2179 - mae: 1.1788 - val_loss: 880.1465 - val_mae: 1.4125
# Epoch 196/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 721.0941 - mae: 1.1973 - val_loss: 869.5007 - val_mae: 1.2729
# Epoch 197/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 715.6520 - mae: 1.1301 - val_loss: 873.9709 - val_mae: 1.2463
# Epoch 198/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 711.5764 - mae: 1.1348 - val_loss: 873.6461 - val_mae: 1.2703
# Epoch 199/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 709.8141 - mae: 1.1532 - val_loss: 871.7166 - val_mae: 1.4029
# Epoch 200/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 707.0880 - mae: 1.1229 - val_loss: 872.6129 - val_mae: 1.2958
# Epoch 201/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 704.6668 - mae: 1.1277 - val_loss: 866.6066 - val_mae: 1.2518
# Epoch 202/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 703.2454 - mae: 1.1287 - val_loss: 865.7096 - val_mae: 1.2497
# Epoch 203/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 700.9742 - mae: 1.1338 - val_loss: 855.7014 - val_mae: 1.2582
# Epoch 204/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 698.3741 - mae: 1.1218 - val_loss: 857.9036 - val_mae: 1.3344
# Epoch 205/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 696.0102 - mae: 1.1160 - val_loss: 858.3768 - val_mae: 1.2603
# Epoch 206/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 693.7981 - mae: 1.1225 - val_loss: 849.8289 - val_mae: 1.2374
# Epoch 207/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 691.5214 - mae: 1.1292 - val_loss: 854.8359 - val_mae: 1.2374
# Epoch 208/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 688.8151 - mae: 1.1447 - val_loss: 848.4869 - val_mae: 1.2735
# Epoch 209/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 686.9524 - mae: 1.1346 - val_loss: 853.2883 - val_mae: 1.3133
# Epoch 210/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 684.7983 - mae: 1.1217 - val_loss: 852.2412 - val_mae: 1.2980
# Epoch 211/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 682.9568 - mae: 1.1160 - val_loss: 844.4973 - val_mae: 1.2375
# Epoch 212/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 682.0406 - mae: 1.1217 - val_loss: 841.0015 - val_mae: 1.3255
# Epoch 213/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 678.7498 - mae: 1.1191 - val_loss: 842.4081 - val_mae: 1.2640
# Epoch 214/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 675.7782 - mae: 1.1089 - val_loss: 838.4536 - val_mae: 1.2545
# Epoch 215/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 673.8337 - mae: 1.1121 - val_loss: 838.3766 - val_mae: 1.2309
# Epoch 216/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 672.6020 - mae: 1.1069 - val_loss: 835.9087 - val_mae: 1.2520
# Epoch 217/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 669.4889 - mae: 1.0940 - val_loss: 829.9741 - val_mae: 1.2437
# Epoch 218/1000
# 36/36 [==============================] - 6s 176ms/step - loss: 669.6433 - mae: 1.1203 - val_loss: 831.0542 - val_mae: 1.2632
# Epoch 219/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 667.2344 - mae: 1.1038 - val_loss: 831.7990 - val_mae: 1.3082
# Epoch 220/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 663.9097 - mae: 1.1115 - val_loss: 822.5422 - val_mae: 1.2982
# Epoch 221/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 661.8120 - mae: 1.0861 - val_loss: 823.5140 - val_mae: 1.2335
# Epoch 222/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 660.1077 - mae: 1.0988 - val_loss: 825.7233 - val_mae: 1.2605
# Epoch 223/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 657.8075 - mae: 1.1032 - val_loss: 823.2388 - val_mae: 1.2480
# Epoch 224/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 657.4045 - mae: 1.0954 - val_loss: 826.1946 - val_mae: 1.2725
# Epoch 225/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 653.8742 - mae: 1.1170 - val_loss: 815.4025 - val_mae: 1.2658
# Epoch 226/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 651.4880 - mae: 1.1594 - val_loss: 812.6411 - val_mae: 1.2359
# Epoch 227/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 648.8456 - mae: 1.1058 - val_loss: 826.4075 - val_mae: 1.2461
# Epoch 228/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 647.8832 - mae: 1.0753 - val_loss: 818.4164 - val_mae: 1.2391
# Epoch 229/1000
# 36/36 [==============================] - 6s 181ms/step - loss: 644.3780 - mae: 1.0817 - val_loss: 807.1934 - val_mae: 1.3044
# Epoch 230/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 644.3840 - mae: 1.1299 - val_loss: 808.4835 - val_mae: 1.2890
# Epoch 231/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 641.4166 - mae: 1.0918 - val_loss: 808.5725 - val_mae: 1.2258
# Epoch 232/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 639.3495 - mae: 1.0766 - val_loss: 802.4370 - val_mae: 1.2987
# Epoch 233/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 637.8593 - mae: 1.1060 - val_loss: 807.3976 - val_mae: 1.2871
# Epoch 234/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 635.3525 - mae: 1.0798 - val_loss: 798.7872 - val_mae: 1.2291
# Epoch 235/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 632.5693 - mae: 1.0698 - val_loss: 800.2827 - val_mae: 1.2241
# Epoch 236/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 631.0104 - mae: 1.0719 - val_loss: 797.0040 - val_mae: 1.2544
# Epoch 237/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 628.6917 - mae: 1.0747 - val_loss: 802.4094 - val_mae: 1.2060
# Epoch 238/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 627.6116 - mae: 1.0963 - val_loss: 791.8192 - val_mae: 1.2794
# Epoch 239/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 625.6087 - mae: 1.0824 - val_loss: 793.3872 - val_mae: 1.2564
# Epoch 240/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 623.6664 - mae: 1.0776 - val_loss: 792.3815 - val_mae: 1.2132
# Epoch 241/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 622.0225 - mae: 1.0707 - val_loss: 783.3233 - val_mae: 1.2640
# Epoch 242/1000
# 36/36 [==============================] - 7s 181ms/step - loss: 619.7938 - mae: 1.0763 - val_loss: 788.1637 - val_mae: 1.2102
# Epoch 243/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 619.2397 - mae: 1.0608 - val_loss: 779.5572 - val_mae: 1.2803
# Epoch 244/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 615.5511 - mae: 1.1110 - val_loss: 785.1528 - val_mae: 1.2416
# Epoch 245/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 613.7610 - mae: 1.0825 - val_loss: 779.8889 - val_mae: 1.2099
# Epoch 246/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 611.0607 - mae: 1.0636 - val_loss: 783.0966 - val_mae: 1.2042
# Epoch 247/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 610.2732 - mae: 1.0547 - val_loss: 786.4235 - val_mae: 1.2420
# Epoch 248/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 609.0605 - mae: 1.0583 - val_loss: 774.2715 - val_mae: 1.2241
# Epoch 249/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 605.7590 - mae: 1.0718 - val_loss: 783.7602 - val_mae: 1.2284
# Epoch 250/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 606.1770 - mae: 1.0811 - val_loss: 775.5632 - val_mae: 1.3421
# Epoch 251/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 603.5661 - mae: 1.1017 - val_loss: 776.3627 - val_mae: 1.2395
# Epoch 252/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 600.6610 - mae: 1.0634 - val_loss: 773.2798 - val_mae: 1.3042
# Epoch 253/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 599.7810 - mae: 1.0744 - val_loss: 766.4813 - val_mae: 1.2385
# Epoch 254/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 596.8958 - mae: 1.0603 - val_loss: 775.9738 - val_mae: 1.2401
# Epoch 255/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 594.2906 - mae: 1.0272 - val_loss: 770.0840 - val_mae: 1.2137
# Epoch 256/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 594.4896 - mae: 1.0678 - val_loss: 761.1310 - val_mae: 1.2103
# Epoch 257/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 590.2298 - mae: 1.0695 - val_loss: 765.1120 - val_mae: 1.2241
# Epoch 258/1000
# 36/36 [==============================] - 7s 182ms/step - loss: 588.9723 - mae: 1.0562 - val_loss: 762.5826 - val_mae: 1.2163
# Epoch 259/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 588.0447 - mae: 1.0389 - val_loss: 762.6128 - val_mae: 1.2497
# Epoch 260/1000
# 36/36 [==============================] - 6s 181ms/step - loss: 585.7546 - mae: 1.0450 - val_loss: 758.2905 - val_mae: 1.2267
# Epoch 261/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 585.1738 - mae: 1.0413 - val_loss: 759.1902 - val_mae: 1.2924
# Epoch 262/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 581.8214 - mae: 1.0542 - val_loss: 753.3388 - val_mae: 1.2254
# Epoch 263/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 580.1710 - mae: 1.0246 - val_loss: 753.9993 - val_mae: 1.2243
# Epoch 264/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 577.4930 - mae: 1.0276 - val_loss: 757.4137 - val_mae: 1.1919
# Epoch 265/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 576.1125 - mae: 1.0349 - val_loss: 750.4507 - val_mae: 1.1989
# Epoch 266/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 575.7543 - mae: 1.0733 - val_loss: 755.0108 - val_mae: 1.2318
# Epoch 267/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 573.0845 - mae: 1.0667 - val_loss: 747.8987 - val_mae: 1.2317
# Epoch 268/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 573.0192 - mae: 1.0434 - val_loss: 757.7392 - val_mae: 1.2114
# Epoch 269/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 570.7947 - mae: 1.0312 - val_loss: 756.1931 - val_mae: 1.2433
# Epoch 270/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 568.8865 - mae: 1.0829 - val_loss: 751.4969 - val_mae: 1.2214
# Epoch 271/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 577.8353 - mae: 1.2253 - val_loss: 765.1067 - val_mae: 1.3777
# Epoch 272/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 582.2515 - mae: 1.1701 - val_loss: 735.8265 - val_mae: 1.2489
# Epoch 273/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 570.7395 - mae: 1.0854 - val_loss: 740.3378 - val_mae: 1.3075
# Epoch 274/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 563.2700 - mae: 1.0546 - val_loss: 743.2530 - val_mae: 1.2334
# Epoch 275/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 559.9565 - mae: 1.0067 - val_loss: 741.5286 - val_mae: 1.2124
# Epoch 276/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 557.6732 - mae: 1.0207 - val_loss: 737.5916 - val_mae: 1.2265
# Epoch 277/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 558.8779 - mae: 1.0189 - val_loss: 730.3696 - val_mae: 1.2186
# Epoch 278/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 553.7766 - mae: 1.0024 - val_loss: 739.7576 - val_mae: 1.1961
# Epoch 279/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 552.4437 - mae: 0.9866 - val_loss: 729.0945 - val_mae: 1.1963
# Epoch 280/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 552.4244 - mae: 1.0353 - val_loss: 735.1434 - val_mae: 1.2530
# Epoch 281/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 551.3513 - mae: 1.0273 - val_loss: 731.2087 - val_mae: 1.2120
# Epoch 282/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 548.7832 - mae: 1.0042 - val_loss: 722.7881 - val_mae: 1.1944
# Epoch 283/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 548.9714 - mae: 1.0014 - val_loss: 721.5030 - val_mae: 1.2955
# Epoch 284/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 545.2446 - mae: 1.0019 - val_loss: 737.8481 - val_mae: 1.2072
# Epoch 285/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 542.7115 - mae: 0.9806 - val_loss: 731.5481 - val_mae: 1.1805
# Epoch 286/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 541.3898 - mae: 0.9808 - val_loss: 734.3935 - val_mae: 1.1871
# Epoch 287/1000
# 36/36 [==============================] - 6s 179ms/step - loss: 541.8396 - mae: 0.9871 - val_loss: 726.7289 - val_mae: 1.2066
# Epoch 288/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 542.4879 - mae: 1.0048 - val_loss: 721.3906 - val_mae: 1.2248
# Epoch 289/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 537.2054 - mae: 0.9834 - val_loss: 725.3148 - val_mae: 1.2625
# Epoch 290/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 537.0257 - mae: 0.9993 - val_loss: 712.1596 - val_mae: 1.1986
# Epoch 291/1000
# 36/36 [==============================] - 6s 180ms/step - loss: 534.9448 - mae: 0.9687 - val_loss: 712.7429 - val_mae: 1.1773
# Epoch 292/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 532.2299 - mae: 0.9780 - val_loss: 714.6078 - val_mae: 1.1763
# Epoch 293/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 530.4821 - mae: 0.9785 - val_loss: 713.2785 - val_mae: 1.1719
# Epoch 294/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 528.8430 - mae: 0.9658 - val_loss: 717.6461 - val_mae: 1.1794
# Epoch 295/1000
# 36/36 [==============================] - 6s 177ms/step - loss: 529.1422 - mae: 0.9894 - val_loss: 708.2498 - val_mae: 1.1741
# Epoch 296/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 526.2043 - mae: 0.9765 - val_loss: 711.1494 - val_mae: 1.1735
# Epoch 297/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 523.8708 - mae: 0.9792 - val_loss: 715.0974 - val_mae: 1.1720
# Epoch 298/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 523.6935 - mae: 0.9842 - val_loss: 710.3983 - val_mae: 1.2131
# Epoch 299/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 521.8539 - mae: 0.9837 - val_loss: 706.0037 - val_mae: 1.1736
# Epoch 300/1000
# 36/36 [==============================] - 6s 178ms/step - loss: 523.4706 - mae: 0.9752 - val_loss: 705.5461 - val_mae: 1.2420
# Epoch 301/1000
#  1/36 [..............................] - ETA: 5s - loss: 505.1810 - mae: 1.0209

# %%
history_valence = model_valence.fit(X_train, y_train_valence, epochs=1000, batch_size=32, validation_split=0.2)

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):
    # Plot loss
    plt.figure(figsize=(12, 5))

    # Plot training & validation loss values
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{title} Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')

    # Plot training & validation MAE values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['mae'])
    plt.plot(history.history['val_mae'])
    plt.title(f'{title} Mean Absolute Error')
    plt.ylabel('MAE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')

    plt.tight_layout()
    plt.show()

# Plot history for label 1
plot_history(history_arousal, "Arousal")

# Plot history for label 2
plot_history(history_valence, "Valence")

# %%
# Evaluate the model on test set
loss_arousal, mae_arousal = model_arousal.evaluate(X_test, y_test_arousal)
loss_valence, mae_valence = model_valence.evaluate(X_test, y_test_valence)

print(f'Label 1 - Test Loss: {loss_arousal}, Test MAE: {mae_arousal}')
print(f'Label 2 - Test Loss: {loss_valence}, Test MAE: {mae_valence}')

# %%
model_arousal.save('model_arousal.h5')
model_valence.save('model_valence.h5')

print("Models saved successfully.")
